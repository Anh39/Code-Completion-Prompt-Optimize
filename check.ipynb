# %%
# !nvidia-smi
# Out:
# Sun Mar 29 22:49:15 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 590.48.01              Driver Version: 590.48.01      CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3090        On  |   00000000:23:00.0 Off |                  N/A |
# | 30%   54C    P2            319W /  350W |   18795MiB /  24576MiB |     97%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !bash eval_pass.sh
# Out:
# Running command:
# python humaneval-fim-pass.py --model_name_or_path Qwen/Qwen2.5-Coder-1.5B --input_dir data/HumanEval --model_output_dir model_outputs/qwen25-15-base --eval_output_dir eval_outputs/qwen25-15-base --tasks single-line multi-line span span-light --max_seq_length 4096 --max_model_length 5000 --workers 16 --tp 1 --vram_utilization 0.9 --lora_path ../qwen25-15-c-ft/checkpoint-638
# INFO 03-26 08:53:27 [__init__.py:235] Automatically detected platform cuda.
# `torch_dtype` is deprecated! Use `dtype` instead!
# INFO 03-26 08:53:37 [config.py:1604] Using max model len 5000
# INFO 03-26 08:53:37 [config.py:2434] Chunked prefill is enabled with max_num_batched_tokens=8192.
# INFO 03-26 08:53:38 [core.py:572] Waiting for init message from front-end.
# ...
